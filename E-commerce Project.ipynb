# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Data Reading

# %%
df = pd.read_csv('Ecommerce_data.csv')
pd.DataFrame
print(df)
# Out:
#      customer_id customer_first_name customer_last_name    category_name  \
# 0     C_ID_45866                Mary             Fuller  Office Supplies
# 1     C_ID_44932                Alan            Edelman  Office Supplies
# 2     C_ID_70880                Mary             Gayman  Office Supplies
# 3     C_ID_33157             Raymond              Eason  Office Supplies
# 4     C_ID_58303                Mary           Gonzalez        Furniture
# ...          ...                 ...                ...              ...
# 4630  C_ID_48636             Frances              Jones        Furniture
# 4631  C_ID_73306              Janice             Kiefer  Office Supplies
# 4632  C_ID_27671             Anthony             Miller  Office Supplies
# 4633  C_ID_50006                Eric             Miller  Office Supplies
# 4634  C_ID_27671                Eric            Company  Office Supplies
#
#                                            product_name customer_segment  \
# 0                                            Xerox 1913        Corporate
# 1                    #6 3/4 Gummed Flap White Envelopes        Corporate
# 2                       Belkin 8 Outlet Surge Protector         Consumer
# 3                  GBC VeloBinder Manual Binding System        Corporate
# 4                         Eldon Pizzaz Desk Accessories      Home Office
# ...                                                 ...              ...
# 4630  Bush Andora Conference Table, Maple/Graphite G...      Home Office
# 4631                                         Newell 307         Consumer
# 4632  Panasonic KP-380BK Classic Electric Pencil Sha...         Consumer
# 4633  Panasonic KP-4ABK Battery-Operated Pencil Shar...         Consumer
# 4634                  BIC Brite Liner Grip Highlighters         Consumer
#
#      customer_city customer_state customer_country customer_region  ...  \
# 0     New Rochelle       New York    United States            East  ...
# 1          Houston          Texas    United States         Central  ...
# 2       Louisville       Kentucky    United States           South  ...
# 3          Chicago       Illinois    United States         Central  ...
# 4     Philadelphia   Pennsylvania    United States            East  ...
# ...            ...            ...              ...             ...  ...
# 4630        Lorain           Ohio    United States            East  ...
# 4631   Springfield       Missouri    United States         Central  ...
# 4632       Chicago       Illinois    United States         Central  ...
# 4633        Lorain           Ohio    United States            East  ...
# 4634        Lorain           Ohio    United States            East  ...
#
#       order_date      order_id   ship_date   shipping_type  \
# 0      11/5/2022  O_ID_3001072   11/7/2022    Second Class
# 1     20-06-2022  O_ID_3009170  23-06-2022    Second Class
# 2     25-06-2022  O_ID_3047567  30-06-2022  Standard Class
# 3      10/6/2022  O_ID_3060575  10/10/2022    Second Class
# 4       2/5/2022  O_ID_3064311    8/1/2022     First Class
# ...          ...           ...         ...             ...
# 4630  28-03-2021  O_ID_3004641  30-03-2021    Second Class
# 4631  28-12-2021  O_ID_3004642  30-12-2021    Second Class
# 4632    5/9/2021  O_ID_3004643   5/11/2021    Second Class
# 4633  26-01-2021  O_ID_3004644  28-01-2021    Second Class
# 4634  26-01-2021  O_ID_3004645  28-01-2021    Second Class
#
#      days_for_shipment_scheduled  days_for_shipment_real  order_item_discount  \
# 0                              2                       2                 35.0
# 1                              2                       3                 85.0
# 2                              4                       5                 75.0
# 3                              2                       4                 60.0
# 4                              1                       2                125.0
# ...                          ...                     ...                  ...
# 4630                           2                       2                  1.8
# 4631                           2                       2                 10.0
# 4632                           2                       2                 48.0
# 4633                           2                       2                 45.0
# 4634                           2                       2                 10.8
#
#       sales_per_order  order_quantity  profit_per_order
# 0          500.000000               5        223.199997
# 1          500.000000               5        199.199997
# 2           44.000000               5        195.500000
# 3          254.000000               1        220.000000
# 4          500.000000               1         97.500000
# ...               ...             ...               ...
# 4630        17.990000               1          5.260000
# 4631        99.989998               1        -62.990002
# 4632       111.000000               1         70.400002
# 4633       299.980011               1         68.849998
# 4634        59.990002               1        -73.000000
#
# [4635 rows x 21 columns]

# %% [markdown]
# #  By default, shows the first 10 rows

# %%
(df.head(10))
# Out:
#   customer_id customer_first_name customer_last_name    category_name  \
# 0  C_ID_45866                Mary             Fuller  Office Supplies
# 1  C_ID_44932                Alan            Edelman  Office Supplies
# 2  C_ID_70880                Mary             Gayman  Office Supplies
# 3  C_ID_33157             Raymond              Eason  Office Supplies
# 4  C_ID_58303                Mary           Gonzalez        Furniture
# 5  C_ID_34556                 Joe        Leatherbury  Office Supplies
# 6  C_ID_56882                Mary            Etezadi  Office Supplies
# 7  C_ID_51638              Andrea           O'Briant  Office Supplies
# 8  C_ID_60578                Mary            Etezadi  Office Supplies
# 9  C_ID_55200                Mary            Etezadi  Office Supplies
#
#                                         product_name customer_segment  \
# 0                                         Xerox 1913        Corporate
# 1                 #6 3/4 Gummed Flap White Envelopes        Corporate
# 2                    Belkin 8 Outlet Surge Protector         Consumer
# 3               GBC VeloBinder Manual Binding System        Corporate
# 4                      Eldon Pizzaz Desk Accessories      Home Office
# 5     Hoover Shoulder Vac Commercial Portable Vacuum      Home Office
# 6            Rogers Handheld Barrel Pencil Sharpener      Home Office
# 7  Dixon Prang Watercolor Pencils, 10-Color Set w...        Corporate
# 8                Ibico Hi-Tech Manual Binding System      Home Office
# 9          Alliance Super-Size Bands, Assorted Sizes      Home Office
#
#   customer_city  customer_state customer_country customer_region  ...  \
# 0  New Rochelle        New York    United States            East  ...
# 1       Houston           Texas    United States         Central  ...
# 2    Louisville        Kentucky    United States           South  ...
# 3       Chicago        Illinois    United States         Central  ...
# 4  Philadelphia    Pennsylvania    United States            East  ...
# 5      Columbia  South Carolina    United States           South  ...
# 6     Henderson        Kentucky    United States           South  ...
# 7        Athens         Georgia    United States           South  ...
# 8     Henderson        Kentucky    United States           South  ...
# 9     Henderson        Kentucky    United States           South  ...
#
#    order_date      order_id   ship_date   shipping_type  \
# 0   11/5/2022  O_ID_3001072   11/7/2022    Second Class
# 1  20-06-2022  O_ID_3009170  23-06-2022    Second Class
# 2  25-06-2022  O_ID_3047567  30-06-2022  Standard Class
# 3   10/6/2022  O_ID_3060575  10/10/2022    Second Class
# 4    2/5/2022  O_ID_3064311    8/1/2022     First Class
# 5  24-06-2022  O_ID_3074984  28-06-2022  Standard Class
# 6   7/10/2022  O_ID_3000007  16-04-2022  Standard Class
# 7  26-01-2022  O_ID_3000008  30-01-2022  Standard Class
# 8    9/3/2022  O_ID_3000009    9/7/2022  Standard Class
# 9  19-03-2022  O_ID_3000010  25-03-2022  Standard Class
#
#   days_for_shipment_scheduled  days_for_shipment_real  order_item_discount  \
# 0                         2.0                     2.0                 35.0
# 1                         2.0                     3.0                 85.0
# 2                         4.0                     5.0                 75.0
# 3                         2.0                     4.0                 60.0
# 4                         1.0                     2.0                125.0
# 5                         4.0                     4.0                 80.0
# 6                         4.0                     3.0                 45.0
# 7                         4.0                     4.0                 45.0
# 8                         4.0                     4.0                 48.0
# 9                         4.0                     6.0                 48.0
#
#    sales_per_order  order_quantity  profit_per_order
# 0       500.000000             5.0        223.199997
# 1       500.000000             5.0        199.199997
# 2        44.000000             5.0        195.500000
# 3       254.000000             1.0        220.000000
# 4       500.000000             1.0         97.500000
# 5       500.000000             2.0       -349.859985
# 6       299.980011             5.0         71.400002
# 7       299.980011             5.0        -31.870001
# 8       299.980011             5.0        118.430000
# 9       299.980011             5.0         78.870003
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Shows the last 10 rows

# %%
(df.tail(10))
# Out:
#       customer_id customer_first_name customer_last_name    category_name  \
# 27769  C_ID_49463               Kathy           Wiediger  Office Supplies
# 27770  C_ID_46173               Peter           Brittain  Office Supplies
# 27771  C_ID_47128             Patrick           Ashbrook  Office Supplies
# 27772  C_ID_45773                Mary           Overcash  Office Supplies
# 27773  C_ID_46443               Kathy             Reiter  Office Supplies
# 27774  C_ID_43813             Carolyn           Ashbrook  Office Supplies
# 27775  C_ID_47128               Kathy         Cartwright  Office Supplies
# 27776  C_ID_49603             Carolyn           Wiediger  Office Supplies
# 27777  C_ID_49603               Kelly           Overcash       Technology
# 27778  C_ID_49603             Patrick         Cartwright       Technology
#
#                                             product_name customer_segment  \
# 27769               GBC VeloBinder Manual Binding System      Home Office
# 27770              Cardinal Holdit Business Card Pockets      Home Office
# 27771                                Stockwell Push Pins         Consumer
# 27772                                          Avery 517         Consumer
# 27773                                          Avery 474         Consumer
# 27774                                          Xerox 225      Home Office
# 27775  Rediform S.O.S. 1-Up Phone Message Bk, 4-1/4x3...         Consumer
# 27776     Carina Media Storage Towers in Natural & Black        Corporate
# 27777              Logitech Wireless Touch Keyboard K400         Consumer
# 27778                      Lexmark MX611dhe Monochrome L              NaN
#
#        customer_city customer_state customer_country customer_region  ...  \
# 27769  New York City       New York    United States            East  ...
# 27770      San Diego     California    United States            West  ...
# 27771  New York City       New York    United States            East  ...
# 27772  New York City       New York    United States            East  ...
# 27773         Denver       Colorado    United States            West  ...
# 27774   Philadelphia   Pennsylvania    United States            East  ...
# 27775  New York City       New York    United States            East  ...
# 27776   Philadelphia   Pennsylvania    United States            East  ...
# 27777        Detroit       Michigan    United States         Central  ...
# 27778            NaN            NaN              NaN             NaN  ...
#
#        order_date      order_id   ship_date   shipping_type  \
# 27769  25-09-2021  O_ID_3027821  28-09-2021  Standard Class
# 27770    2/9/2021  O_ID_3027822   12/2/2021  Standard Class
# 27771  25-09-2021  O_ID_3027823  28-09-2021  Standard Class
# 27772  21-10-2021  O_ID_3027824  24-10-2021  Standard Class
# 27773  25-09-2021  O_ID_3027825  28-09-2021  Standard Class
# 27774  17-10-2021  O_ID_3027826  20-10-2021  Standard Class
# 27775  25-09-2021  O_ID_3027827  28-09-2021  Standard Class
# 27776  17-10-2021  O_ID_3027828  20-10-2021  Standard Class
# 27777  29-08-2021  O_ID_3027829    1/9/2021  Standard Class
# 27778         NaN           NaN         NaN             NaN
#
#       days_for_shipment_scheduled  days_for_shipment_real  \
# 27769                         4.0                     3.0
# 27770                         4.0                     3.0
# 27771                         4.0                     3.0
# 27772                         4.0                     3.0
# 27773                         4.0                     3.0
# 27774                         4.0                     3.0
# 27775                         4.0                     3.0
# 27776                         4.0                     3.0
# 27777                         4.0                     3.0
# 27778                         NaN                     NaN
#
#        order_item_discount  sales_per_order  order_quantity  profit_per_order
# 27769                15.60       129.990005             1.0         37.180000
# 27770                 4.55        34.990002             1.0          3.810000
# 27771                39.00       299.980011             1.0        122.660004
# 27772                16.90       129.990005             1.0         35.400002
# 27773                16.90       129.990005             1.0         39.580002
# 27774                45.00       299.980011             1.0         92.559998
# 27775                19.50       129.990005             1.0        -23.980000
# 27776                48.00       299.980011             1.0         91.470001
# 27777                17.00        99.989998             1.0         34.029999
# 27778                  NaN              NaN             NaN               NaN
#
# [10 rows x 21 columns]

# %% [markdown]
#  # Check for missing values
#
#  # Returns True for missing values

# %%
(df.isnull())
# Out:
#        customer_id  customer_first_name  customer_last_name  category_name  \
# 0            False                False               False          False
# 1            False                False               False          False
# 2            False                False               False          False
# 3            False                False               False          False
# 4            False                False               False          False
# ...            ...                  ...                 ...            ...
# 27774        False                False               False          False
# 27775        False                False               False          False
# 27776        False                False               False          False
# 27777        False                False               False          False
# 27778        False                False               False          False
#
#        product_name  customer_segment  customer_city  customer_state  \
# 0             False             False          False           False
# 1             False             False          False           False
# 2             False             False          False           False
# 3             False             False          False           False
# 4             False             False          False           False
# ...             ...               ...            ...             ...
# 27774         False             False          False           False
# 27775         False             False          False           False
# 27776         False             False          False           False
# 27777         False             False          False           False
# 27778         False              True           True            True
#
#        customer_country  customer_region  ...  order_date  order_id  \
# 0                 False            False  ...       False     False
# 1                 False            False  ...       False     False
# 2                 False            False  ...       False     False
# 3                 False            False  ...       False     False
# 4                 False            False  ...       False     False
# ...                 ...              ...  ...         ...       ...
# 27774             False            False  ...       False     False
# 27775             False            False  ...       False     False
# 27776             False            False  ...       False     False
# 27777             False            False  ...       False     False
# 27778              True             True  ...        True      True
#
#        ship_date  shipping_type  days_for_shipment_scheduled  \
# 0          False          False                        False
# 1          False          False                        False
# 2          False          False                        False
# 3          False          False                        False
# 4          False          False                        False
# ...          ...            ...                          ...
# 27774      False          False                        False
# 27775      False          False                        False
# 27776      False          False                        False
# 27777      False          False                        False
# 27778       True           True                         True
#
#        days_for_shipment_real  order_item_discount  sales_per_order  \
# 0                       False                False            False
# 1                       False                False            False
# 2                       False                False            False
# 3                       False                False            False
# 4                       False                False            False
# ...                       ...                  ...              ...
# 27774                   False                False            False
# 27775                   False                False            False
# 27776                   False                False            False
# 27777                   False                False            False
# 27778                    True                 True             True
#
#        order_quantity  profit_per_order
# 0               False             False
# 1               False             False
# 2               False             False
# 3               False             False
# 4               False             False
# ...               ...               ...
# 27774           False             False
# 27775           False             False
# 27776           False             False
# 27777           False             False
# 27778            True              True
#
# [27779 rows x 21 columns]

# %% [markdown]
# # Count of missing values per column

# %%
(df.isnull().sum())
# Out:
# customer_id                    0
# customer_first_name            0
# customer_last_name             0
# category_name                  0
# product_name                   0
# customer_segment               1
# customer_city                  1
# customer_state                 1
# customer_country               1
# customer_region                1
# delivery_status                1
# order_date                     1
# order_id                       1
# ship_date                      1
# shipping_type                  1
# days_for_shipment_scheduled    1
# days_for_shipment_real         1
# order_item_discount            1
# sales_per_order                1
# order_quantity                 1
# profit_per_order               1
# dtype: int64

# %% [markdown]
# # Gives column names, data types, and non-null counts

# %%
(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27779 entries, 0 to 27778
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   customer_id                  27779 non-null  object
#  1   customer_first_name          27779 non-null  object
#  2   customer_last_name           27779 non-null  object
#  3   category_name                27779 non-null  object
#  4   product_name                 27779 non-null  object
#  5   customer_segment             27778 non-null  object
#  6   customer_city                27778 non-null  object
#  7   customer_state               27778 non-null  object
#  8   customer_country             27778 non-null  object
#  9   customer_region              27778 non-null  object
#  10  delivery_status              27778 non-null  object
#  11  order_date                   27778 non-null  object
#  12  order_id                     27778 non-null  object
#  13  ship_date                    27778 non-null  object
#  14  shipping_type                27778 non-null  object
#  15  days_for_shipment_scheduled  27778 non-null  float64
#  16  days_for_shipment_real       27778 non-null  float64
#  17  order_item_discount          27778 non-null  float64
#  18  sales_per_order              27778 non-null  float64
#  19  order_quantity               27778 non-null  float64
#  20  profit_per_order             27778 non-null  float64
# dtypes: float64(6), object(15)
# memory usage: 4.5+ MB

# %% [markdown]
#  # Shows count, mean, min, max, etc.

# %%
(df.describe())
# Out:
#        days_for_shipment_scheduled  days_for_shipment_real  \
# count                 27778.000000            27778.000000
# mean                      3.462704                2.952120
# std                       1.136345                1.251019
# min                       0.000000                0.000000
# 25%                       4.000000                2.000000
# 50%                       4.000000                3.000000
# 75%                       4.000000                4.000000
# max                       4.000000                6.000000
#
#        order_item_discount  sales_per_order  order_quantity  profit_per_order
# count         27778.000000     27778.000000    27778.000000      27778.000000
# mean             23.056606       215.189442        1.970516         25.399859
# std              24.447139       150.027488        1.388898        114.263606
# min               0.000000         9.990000        1.000000      -2184.000000
# 25%               6.000000       119.980003        1.000000          7.970000
# 50%              16.000000       199.949997        1.000000         34.470001
# 75%              32.500000       299.980011        3.000000         74.400002
# max             400.000000      1999.989990        5.000000       2600.000000

# %% [markdown]
# #Data cleaning

# %%
df_cleaned = df.dropna()
(df_cleaned)
# Out:
#      customer_id customer_first_name customer_last_name    category_name  \
# 0     C_ID_45866                Mary             Fuller  Office Supplies
# 1     C_ID_44932                Alan            Edelman  Office Supplies
# 2     C_ID_70880                Mary             Gayman  Office Supplies
# 3     C_ID_33157             Raymond              Eason  Office Supplies
# 4     C_ID_58303                Mary           Gonzalez        Furniture
# ...          ...                 ...                ...              ...
# 4630  C_ID_48636             Frances              Jones        Furniture
# 4631  C_ID_73306              Janice             Kiefer  Office Supplies
# 4632  C_ID_27671             Anthony             Miller  Office Supplies
# 4633  C_ID_50006                Eric             Miller  Office Supplies
# 4634  C_ID_27671                Eric            Company  Office Supplies
#
#                                            product_name customer_segment  \
# 0                                            Xerox 1913        Corporate
# 1                    #6 3/4 Gummed Flap White Envelopes        Corporate
# 2                       Belkin 8 Outlet Surge Protector         Consumer
# 3                  GBC VeloBinder Manual Binding System        Corporate
# 4                         Eldon Pizzaz Desk Accessories      Home Office
# ...                                                 ...              ...
# 4630  Bush Andora Conference Table, Maple/Graphite G...      Home Office
# 4631                                         Newell 307         Consumer
# 4632  Panasonic KP-380BK Classic Electric Pencil Sha...         Consumer
# 4633  Panasonic KP-4ABK Battery-Operated Pencil Shar...         Consumer
# 4634                  BIC Brite Liner Grip Highlighters         Consumer
#
#      customer_city customer_state customer_country customer_region  ...  \
# 0     New Rochelle       New York    United States            East  ...
# 1          Houston          Texas    United States         Central  ...
# 2       Louisville       Kentucky    United States           South  ...
# 3          Chicago       Illinois    United States         Central  ...
# 4     Philadelphia   Pennsylvania    United States            East  ...
# ...            ...            ...              ...             ...  ...
# 4630        Lorain           Ohio    United States            East  ...
# 4631   Springfield       Missouri    United States         Central  ...
# 4632       Chicago       Illinois    United States         Central  ...
# 4633        Lorain           Ohio    United States            East  ...
# 4634        Lorain           Ohio    United States            East  ...
#
#       order_date      order_id   ship_date   shipping_type  \
# 0      11/5/2022  O_ID_3001072   11/7/2022    Second Class
# 1     20-06-2022  O_ID_3009170  23-06-2022    Second Class
# 2     25-06-2022  O_ID_3047567  30-06-2022  Standard Class
# 3      10/6/2022  O_ID_3060575  10/10/2022    Second Class
# 4       2/5/2022  O_ID_3064311    8/1/2022     First Class
# ...          ...           ...         ...             ...
# 4630  28-03-2021  O_ID_3004641  30-03-2021    Second Class
# 4631  28-12-2021  O_ID_3004642  30-12-2021    Second Class
# 4632    5/9/2021  O_ID_3004643   5/11/2021    Second Class
# 4633  26-01-2021  O_ID_3004644  28-01-2021    Second Class
# 4634  26-01-2021  O_ID_3004645  28-01-2021    Second Class
#
#      days_for_shipment_scheduled  days_for_shipment_real  order_item_discount  \
# 0                              2                       2                 35.0
# 1                              2                       3                 85.0
# 2                              4                       5                 75.0
# 3                              2                       4                 60.0
# 4                              1                       2                125.0
# ...                          ...                     ...                  ...
# 4630                           2                       2                  1.8
# 4631                           2                       2                 10.0
# 4632                           2                       2                 48.0
# 4633                           2                       2                 45.0
# 4634                           2                       2                 10.8
#
#       sales_per_order  order_quantity  profit_per_order
# 0          500.000000               5        223.199997
# 1          500.000000               5        199.199997
# 2           44.000000               5        195.500000
# 3          254.000000               1        220.000000
# 4          500.000000               1         97.500000
# ...               ...             ...               ...
# 4630        17.990000               1          5.260000
# 4631        99.989998               1        -62.990002
# 4632       111.000000               1         70.400002
# 4633       299.980011               1         68.849998
# 4634        59.990002               1        -73.000000
#
# [4635 rows x 21 columns]

# %%
cleaned_file_path = "Cleaned_Ecommerce_data.csv"
df.to_csv(cleaned_file_path, index=False)
print(f"\nCleaned DataFrame saved to: {cleaned_file_path}")
# Out:
# Cleaned DataFrame saved to: Cleaned_Ecommerce_data.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Load cleaned data

# %%
data = pd.read_csv("Cleaned_Ecommerce_data.csv")

# %% [markdown]
# # Set seaborn style

# %%
sns.set_theme(style="whitegrid")

# %% [markdown]
# # Display basic information about the data

# %%
print("Dataset Overview:")
data.info()
print("\nSummary Statistics:")
data.describe()
# Out:
# Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37059 entries, 0 to 37058
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   customer_id                  37059 non-null  object
#  1   customer_first_name          37059 non-null  object
#  2   customer_last_name           37059 non-null  object
#  3   category_name                37058 non-null  object
#  4   product_name                 37058 non-null  object
#  5   customer_segment             37058 non-null  object
#  6   customer_city                37058 non-null  object
#  7   customer_state               37058 non-null  object
#  8   customer_country             37058 non-null  object
#  9   customer_region              37058 non-null  object
#  10  delivery_status              37058 non-null  object
#  11  order_date                   37058 non-null  object
#  12  order_id                     37058 non-null  object
#  13  ship_date                    37058 non-null  object
#  14  shipping_type                37058 non-null  object
#  15  days_for_shipment_scheduled  37058 non-null  float64
#  16  days_for_shipment_real       37058 non-null  float64
#  17  order_item_discount          37058 non-null  float64
#  18  sales_per_order              37058 non-null  float64
#  19  order_quantity               37058 non-null  float64
#  20  profit_per_order             37058 non-null  float64
# dtypes: float64(6), object(15)
# memory usage: 5.9+ MB
#
# Summary Statistics:
#        days_for_shipment_scheduled  days_for_shipment_real  \
# count                 37058.000000            37058.000000
# mean                      3.267365                2.808921
# std                       1.319518                1.306353
# min                       0.000000                0.000000
# 25%                       2.000000                2.000000
# 50%                       4.000000                3.000000
# 75%                       4.000000                4.000000
# max                       4.000000                6.000000
#
#        order_item_discount  sales_per_order  order_quantity  profit_per_order
# count         37058.000000     37058.000000    37058.000000      37058.000000
# mean             22.742675       215.524751        2.052323         25.240275
# std              23.943781       145.971307        1.444940        111.462415
# min               0.000000         9.990000        1.000000      -2184.000000
# 25%               6.000000       123.000000        1.000000          7.940000
# 50%              15.980000       199.979996        1.000000         34.320000
# 75%              32.389999       299.980011        3.000000         73.709999
# max             400.000000      1999.989990        5.000000       2600.000000

# %% [markdown]
# # Remove or handle missing values

# %%
data = data.dropna()
print("\nData after handling missing values:")
data.head(10)
# Out:
# Data after handling missing values:
#   customer_id customer_first_name customer_last_name    category_name  \
# 0  C_ID_45866                Mary             Fuller  Office Supplies
# 1  C_ID_44932                Alan            Edelman  Office Supplies
# 2  C_ID_70880                Mary             Gayman  Office Supplies
# 3  C_ID_33157             Raymond              Eason  Office Supplies
# 4  C_ID_58303                Mary           Gonzalez        Furniture
# 5  C_ID_34556                 Joe        Leatherbury  Office Supplies
# 6  C_ID_56882                Mary            Etezadi  Office Supplies
# 7  C_ID_51638              Andrea           O'Briant  Office Supplies
# 8  C_ID_60578                Mary            Etezadi  Office Supplies
# 9  C_ID_55200                Mary            Etezadi  Office Supplies
#
#                                         product_name customer_segment  \
# 0                                         Xerox 1913        Corporate
# 1                 #6 3/4 Gummed Flap White Envelopes        Corporate
# 2                    Belkin 8 Outlet Surge Protector         Consumer
# 3               GBC VeloBinder Manual Binding System        Corporate
# 4                      Eldon Pizzaz Desk Accessories      Home Office
# 5     Hoover Shoulder Vac Commercial Portable Vacuum      Home Office
# 6            Rogers Handheld Barrel Pencil Sharpener      Home Office
# 7  Dixon Prang Watercolor Pencils, 10-Color Set w...        Corporate
# 8                Ibico Hi-Tech Manual Binding System      Home Office
# 9          Alliance Super-Size Bands, Assorted Sizes      Home Office
#
#   customer_city  customer_state customer_country customer_region  ...  \
# 0  New Rochelle        New York    United States            East  ...
# 1       Houston           Texas    United States         Central  ...
# 2    Louisville        Kentucky    United States           South  ...
# 3       Chicago        Illinois    United States         Central  ...
# 4  Philadelphia    Pennsylvania    United States            East  ...
# 5      Columbia  South Carolina    United States           South  ...
# 6     Henderson        Kentucky    United States           South  ...
# 7        Athens         Georgia    United States           South  ...
# 8     Henderson        Kentucky    United States           South  ...
# 9     Henderson        Kentucky    United States           South  ...
#
#    order_date      order_id   ship_date   shipping_type  \
# 0   11/5/2022  O_ID_3001072   11/7/2022    Second Class
# 1  20-06-2022  O_ID_3009170  23-06-2022    Second Class
# 2  25-06-2022  O_ID_3047567  30-06-2022  Standard Class
# 3   10/6/2022  O_ID_3060575  10/10/2022    Second Class
# 4    2/5/2022  O_ID_3064311    8/1/2022     First Class
# 5  24-06-2022  O_ID_3074984  28-06-2022  Standard Class
# 6   7/10/2022  O_ID_3000007  16-04-2022  Standard Class
# 7  26-01-2022  O_ID_3000008  30-01-2022  Standard Class
# 8    9/3/2022  O_ID_3000009    9/7/2022  Standard Class
# 9  19-03-2022  O_ID_3000010  25-03-2022  Standard Class
#
#   days_for_shipment_scheduled  days_for_shipment_real  order_item_discount  \
# 0                         2.0                     2.0                 35.0
# 1                         2.0                     3.0                 85.0
# 2                         4.0                     5.0                 75.0
# 3                         2.0                     4.0                 60.0
# 4                         1.0                     2.0                125.0
# 5                         4.0                     4.0                 80.0
# 6                         4.0                     3.0                 45.0
# 7                         4.0                     4.0                 45.0
# 8                         4.0                     4.0                 48.0
# 9                         4.0                     6.0                 48.0
#
#    sales_per_order  order_quantity  profit_per_order
# 0       500.000000             5.0        223.199997
# 1       500.000000             5.0        199.199997
# 2        44.000000             5.0        195.500000
# 3       254.000000             1.0        220.000000
# 4       500.000000             1.0         97.500000
# 5       500.000000             2.0       -349.859985
# 6       299.980011             5.0         71.400002
# 7       299.980011             5.0        -31.870001
# 8       299.980011             5.0        118.430000
# 9       299.980011             5.0         78.870003
#
# [10 rows x 21 columns]

# %% [markdown]
# #  Top 5 order_quantity (or Products)

# %%
top_categories = data['order_quantity'].value_counts().nlargest(5)
print("\nTop 5 order_quantity values with their counts:")
top_categories
# Out:
# Top 5 order_quantity values with their counts:
# order_quantity
# 1.0    21540
# 5.0     4141
# 2.0     4124
# 4.0     3803
# 3.0     3450
# Name: count, dtype: int64

# %% [markdown]
# Correlation Analysis for Numeric Features

# %%
numeric_data = data.select_dtypes(include=['number'])
correlation_matrix = numeric_data.corr()
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Matrix for Numeric Features")
plt.show()

# %% [markdown]
# #  Distribution Analysis

# %%
numeric_columns = ['days_for_shipment_scheduled', 'days_for_shipment_real',
                   'order_item_discount', 'sales_per_order',
                   'order_quantity', 'profit_per_order']

for col in numeric_columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(data[col], kde=True, bins=30, color='blue')
    plt.title(f"Distribution of {col}")
    plt.show()

# %% [markdown]
# # Outlier Detection

# %%
for col in numeric_columns:
    plt.figure(figsize=(8, 4))
    sns.boxplot(data[col], color='red')
    plt.title(f"Outlier Analysis for {col}")
    plt.show()

# %% [markdown]
# #  Trend Analysis

# %%
data['order_date'] = pd.to_datetime(data['order_date'], errors='coerce')  # Ensure date parsing
sales_trend = data.groupby(data['order_date'].dt.to_period('M'))['sales_per_order'].mean()

plt.figure(figsize=(12, 6))
sales_trend.plot()
plt.title("Monthly Average Sales Per Order")
plt.xlabel("Month")
plt.ylabel("Average Sales")
plt.grid(True)
plt.show()

# %% [markdown]
# # Grouped Analysis
#  Average profit by shipping type

# %%
avg_profit_by_shipping = data.groupby('shipping_type')['profit_per_order'].mean()

plt.figure(figsize=(8, 4))
avg_profit_by_shipping.plot(kind='bar', color='teal')
plt.title("Average Profit by Shipping Type")
plt.xlabel("Shipping Type")
plt.ylabel("Average Profit")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Calculate the top-performing products by sales

# %%
top_products = data.groupby('product_name')['sales_per_order'].sum().sort_values(ascending=False).head(10)
top_products_df = pd.DataFrame({
    'Product Name': top_products.index,
    'Total Sales': top_products.values})
top_products_df
# Out:
#                                  Product Name   Total Sales
# 0                                     Staples  71130.205243
# 1                             Staple envelope  68870.791326
# 2                           Easy-staple paper  61768.255159
# 3                  KI Adjustable-Height Table  28939.058478
# 4                     Staples in misc. colors  26292.450386
# 5                     Avery Non-Stick Binders  25682.898499
# 6                              Staple remover  22711.450373
# 7                     Storex Dura Pro Binders  22395.180410
# 8                  Staple-based wall hangings  21721.308369
# 9  Situations Contoured Folding Chairs, 4/Set  20660.038355

# %% [markdown]
# # Calculate the top customers by total sales

# %%
top_customers = data.groupby('customer_id')['sales_per_order'].sum().sort_values(ascending=False).head(10)
top_customers_df = pd.DataFrame({
    'Customer ID': top_customers.index,
    'Total Sales': top_customers.values})
top_customers_df
# Out:
#   Customer ID  Total Sales
# 0  C_ID_54153  3489.950012
# 1  C_ID_52997  3377.750000
# 2  C_ID_47998  3199.870025
# 3  C_ID_41932  3000.000000
# 4  C_ID_57604  2814.540018
# 5  C_ID_28784  2781.990036
# 6  C_ID_42758  2779.880035
# 7  C_ID_51208  2739.920006
# 8  C_ID_59491  2707.030014
# 9  C_ID_66429  2689.940033

# %% [markdown]
# #Calculate the total profit by category

# %%
top_categories = data.groupby('category_name')['profit_per_order'].sum().sort_values(ascending=False)
top_categories_df = pd.DataFrame({
    'Category Name': top_categories.index,
    'Total Profit': top_categories.values})
top_categories_df
# Out:
#      Category Name   Total Profit
# 0  Office Supplies  968710.521197
# 1        Furniture  345606.710524
# 2       Technology  298662.059737
# 3        Office Su       0.000000

# %% [markdown]
# # Calculate total sales by region

# %%
top_regions = data.groupby('customer_region')['sales_per_order'].sum().sort_values(ascending=False)
top_regions_df = pd.DataFrame({
    'Region': top_regions.index,
    'Total Sales': top_regions.values})
top_regions_df
# Out:
#     Region   Total Sales
# 0     West  4.402020e+06
# 1     East  3.943938e+06
# 2  Central  3.197490e+06
# 3    South  2.232652e+06

# %% [markdown]
# Shipping Type Performance **Analysis**

# %%
shipping_performance = data.groupby('shipping_type').agg({
    'sales_per_order': 'sum',
    'profit_per_order': 'sum',
    'order_quantity': 'sum'
}).sort_values(by='sales_per_order', ascending=False)
shipping_performance_df = pd.DataFrame({
    'Shipping Type': shipping_performance.index,
    'Total Sales': shipping_performance['sales_per_order'].values,
    'Total Profit': shipping_performance['profit_per_order'].values,
    'Total Quantity': shipping_performance['order_quantity'].values})
shipping_performance_df
# Out:
#     Shipping Type   Total Sales  Total Profit  Total Quantity
# 0  Standard Class  9.213895e+06  1.070284e+06         92897.0
# 1    Second Class  2.288718e+06  2.659533e+05         21867.0
# 2     First Class  1.340832e+06  1.752297e+05         12596.0
# 3        Same Day  9.326546e+05  1.015126e+05          9409.0

# %% [markdown]
# ## Customer Segments Analysis

# %%
segment_performance = data.groupby('customer_segment').agg({
    'sales_per_order': 'sum',
    'profit_per_order': 'sum'
}).sort_values(by='sales_per_order', ascending=False)
segment_performance_df = pd.DataFrame({
    'Customer Segment': segment_performance.index,
    'Total Sales': segment_performance['sales_per_order'].values,
    'Total Profit': segment_performance['profit_per_order'].values
})
segment_performance_df
# Out:
#   Customer Segment   Total Sales   Total Profit
# 0         Consumer  7.121963e+06  853756.681177
# 1        Corporate  4.193593e+06  483525.619858
# 2      Home Office  2.460544e+06  275696.990423

# %% [markdown]
# # Calculate the top cities by total sales

# %%
top_cities = data.groupby('customer_city')['sales_per_order'].sum().sort_values(ascending=False).head(10)
top_cities_df = pd.DataFrame({
    'City': top_cities.index,
    'Total Sales': top_cities.values})
top_cities_df
# Out:
#             City   Total Sales
# 0  New York City  1.244157e+06
# 1    Los Angeles  1.053769e+06
# 2   Philadelphia  7.643363e+05
# 3  San Francisco  6.987824e+05
# 4        Seattle  5.829258e+05
# 5        Houston  5.165781e+05
# 6        Chicago  4.329770e+05
# 7       Columbus  3.017418e+05
# 8      San Diego  2.445825e+05
# 9    Springfield  2.134068e+05

# %% [markdown]
# # Delivery Status Distribution

# %%
delivery_status_count = data['delivery_status'].value_counts()
delivery_status_df = pd.DataFrame({
    'Delivery Status': delivery_status_count.index,
    'Count': delivery_status_count.values})
delivery_status_df
# Out:
#      Delivery Status  Count
# 0   Advance shipping  21697
# 1      Late delivery  20046
# 2   Shipping on time  18872
# 3  Shipping canceled   4404

# %% [markdown]
# # Create a colorful Sunburst chart for Category > Product > Region

# %%
fig_sunburst = px.sunburst(
    data_frame=data,
    path=['category_name', 'product_name', 'customer_region'],
    values='sales_per_order',
    color='category_name',
    title='Colorful Sunburst Chart: Sales by Category, Product, and Region',
    color_discrete_sequence=px.colors.qualitative.Set3,
    labels={'sales_per_order': 'Sales'})
fig_sunburst.update_layout(
    margin=dict(t=50, l=25, r=25, b=25),
    title_font_size=18,
    title_x=0.5)

fig_sunburst.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3405a644-7330-4fd2-94c8-887b15488ca0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3405a644-7330-4fd2-94c8-887b15488ca0")) {                    Plotly.newPlot(                        "3405a644-7330-4fd2-94c8-887b15488ca0",                        [{"branchvalues":"total","customdata":[["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Technology"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Technology"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Technology"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Furniture"],["Office Supplies"],["Technology"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Technology"],["Office Supplies"],["Technology"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Furniture"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Technology"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Technology"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Furniture"],["Furniture"],["Office Supplies"],["Furniture"],["Office Supplies"],["Office Supplies"],["Furniture"],["Technology"],["Technology"],["Furniture"],["Technology"],["Technology"],["Furniture"],["Technology"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Furniture"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Technology"],["Office Supplies"],["Technology"],["Office Supplies"],["Furniture"],["Furniture"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Furniture"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Furniture"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Office Supplies"],["Technology"],["Technology"],[ ...
